# %%
# cars basic GBM reg
import matplotlib.pyplot as plt

mean = [ 3.3, 7.96, 10.34, 6.95, 4.62, 1.84]
std_dev = [5.51, 13.7, 19.40, 12.72, 7.28, 3.40 ]
# annotations = ['velocity', ]  # points annotations
annotations = [ 'Displacement', '0-60 mph(s)', 'year', 'weight(lb)' , 'power (hp)', 'cylinders' ]

fig, ax = plt.subplots()
ax.scatter(mean, std_dev)
ax.set_xlim(left=0, right=25)  # x axis limits
ax.set_ylim(bottom=0, top=25)  # y axis limits
ax.set_xlabel('μ*')  # x axis label
ax.set_ylabel('σ')  # y axis label

for index, annotation in enumerate(annotations):
    ax.annotate(annotation, (mean[index], std_dev[index]))

# %%
import matplotlib.pyplot as plt

mean = [ 19.3045, 22.5958, 6.1258, 12.563, 9.5143, 3.074, 16.0503, ]
std_dev = [62.2947, 73.1272, 18.7637, 39.5420, 30.2473, 9.4496, 51.704, ]
# annotations = ['velocity', ]  # points annotations
annotations = [ 'VOL', 'GLEAS', 'RACE', 'DCAPS' , 'DROPS', 'AGE', 'PSA', ]

fig, ax = plt.subplots()
ax.scatter(mean, std_dev)
ax.set_xlim(left=0, right=100)  # x axis limits
ax.set_ylim(bottom=0, top=100)  # y axis limits
ax.set_xlabel('μ*')  # x axis label
ax.set_ylabel('β')  # y axis label

for index, annotation in enumerate(annotations):
    ax.annotate(annotation, (mean[index], std_dev[index]))

# %%
import matplotlib.pyplot as plt

mean = [ 13.88, 2.7, 5.5, 8.3, 11.1]
std_dev = [38.56, 7.7, 15.4, 23.1, 30.8]
# annotations = ['velocity', ]  # points annotations
annotations = [ 'weight', 'f1', 'f2', 'f3' , 'f4']

fig, ax = plt.subplots()
ax.scatter(mean, std_dev)
ax.set_xlim(left=0, right=20)  # x axis limits
ax.set_ylim(bottom=0, top=40)  # y axis limits
ax.set_xlabel('μ*')  # x axis label
ax.set_ylabel('β')  # y axis label

for index, annotation in enumerate(annotations):
    ax.annotate(annotation, (mean[index], std_dev[index]))

# %%
import matplotlib.pyplot as plt; plt.rcdefaults()
import numpy as np
import matplotlib.pyplot as plt

objects = ('PSA', 'DROPS', 'VOL', 'GLEASON', 'AGE', 'RACE', 'DCAPS')
y_pos = np.arange(len(objects))
performance = [17.0, 7.8, 7.5, 3.52, 1.3, 0.0, 0.0]

plt.bar(y_pos, performance, align='center', alpha=0.5)
plt.xticks(y_pos, objects)
plt.ylabel('Feature Importance based on criterion')
plt.title('Features')

plt.show()

# %%
import matplotlib.pyplot as plt; plt.rcdefaults()
import numpy as np
import matplotlib.pyplot as plt

objects = ('cylinders', 'year', 'power (hp)', 'weight (lb)', '0-60 mph (s)', 'displacement (cc)')
y_pos = np.arange(len(objects))
performance = [13693.9, 2432.2, 2382.4, 2348.6, 119, 89.9]


f, ax = plt.subplots(figsize=(9,5))
plt.bar(y_pos, performance, align='center', alpha=0.5)
plt.xticks(y_pos, objects)
plt.ylabel('Permutation Feature Importance')
plt.title('Features')

plt.show()

# %%
import matplotlib.pyplot as plt; plt.rcdefaults()
import numpy as np
import matplotlib.pyplot as plt

objects = ('year', 'weight (lb)', 'cylinders', 'displacement (cc)', 'power(hp)', '0-60 mph (s)')
y_pos = np.arange(len(objects))
performance = [2.52, 2.29, 1.765, 1.4, 1.287, 1.024]


f, ax = plt.subplots(figsize=(9,5))
plt.bar(y_pos, performance, align='center', alpha=0.5)
plt.xticks(y_pos, objects)
plt.ylabel('Permutation Feature Importance')
plt.title('Features')

plt.show()

# %%
import matplotlib.pyplot as plt

mean = [ 3.78, 3.47, 3.12, 1.07, 0.99, 0.586, 0.8]
std_dev = [0.61, 0.38, 0.52, 0.15, 0.113, 0.116, 0.114]
# annotations = ['velocity', ]  # points annotations
annotations = [ 'name', 'economy', 'cylinders', 'displacement' , 'weight', '0-60 mph', 'year']

fig, ax = plt.subplots()
ax.scatter(mean, std_dev)
ax.set_xlim(left=0, right=5)  # x axis limits
ax.set_ylim(bottom=0, top=0.65)  # y axis limits
ax.set_xlabel('μ*')  # x axis label
ax.set_ylabel('β')  # y axis label

for index, annotation in enumerate(annotations):
    ax.annotate(annotation, (mean[index], std_dev[index]))

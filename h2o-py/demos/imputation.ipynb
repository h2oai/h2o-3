# %%
import h2o

# %%
h2o.init()
# Out:
# --------------------------  -------------------------------------
# H2O cluster uptime:         3 minutes 40 seconds 640 milliseconds
# H2O cluster version:        3.1.0.99999
# H2O cluster name:           ece
# H2O cluster total nodes:    1
# H2O cluster total memory:   4.44 GB
# H2O cluster total cores:    8
# H2O cluster allowed cores:  8
# H2O cluster healthy:        True
# H2O Connection ip:          127.0.0.1
# H2O Connection port:        54321
# --------------------------  -------------------------------------

# %%
air = h2o.upload_file(h2o.locate("smalldata/airlines/allyears2k_headers.zip"))
# Out:
# Parse Progress: [                                                  ] 00%
# Parse Progress: [##################################################] 100%
# Uploaded py0cfdef6f-51b4-4957-96df-5083213783e5 into cluster with 43978 rows and 31 cols

# %%
air.dim()
# Out:
# [43978, 31]

# %%
numNAs = air["DepTime"].isna().sum()
print numNAs
# Out:
# 1086.0

# %%
DepTime_mean = air["DepTime"].mean()
print DepTime_mean
# Out:
# 1345.84666138

# %%
h2o.impute(air, "DepTime", method = "median", combine_method="lo")   
numNAs = air["DepTime"].isna().sum()
print numNAs
# Out:
# 0.0

# %%
air = h2o.upload_file(h2o.locate("smalldata/airlines/allyears2k_headers.zip"))
# Out:
# Parse Progress: [                                                  ] 00%
# Parse Progress: [##################################################] 100%
# Uploaded py7b021e17-147c-41b0-a076-2377571f8dc9 into cluster with 43978 rows and 31 cols

# %%
h2o.impute(air, "DepTime", method = "mean", by = ["Origin", "Distance"]).show()
# Out:
# Displaying 10 row(s):
#   Row ID  Year      Month    DayofMonth    DayOfWeek    DepTime    CRSDepTime    ArrTime    CRSArrTime    UniqueCarrier    FlightNum    TailNum    ActualElapsedTime    CRSElapsedTime    AirTime    ArrDelay    DepDelay    Origin    Dest      Distance    TaxiIn    TaxiOut    Cancelled    CancellationCode    Diverted    CarrierDelay    WeatherDelay    NASDelay    SecurityDelay    LateAircraftDelay    IsArrDelayed    IsDepDelayed
# --------  --------  -------  ------------  -----------  ---------  ------------  ---------  ------------  ---------------  -----------  ---------  -------------------  ----------------  ---------  ----------  ----------  --------  --------  ----------  --------  ---------  -----------  ------------------  ----------  --------------  --------------  ----------  ---------------  -------------------  --------------  --------------
#        1  [1987.0]  [10.0]   [14.0]        [3.0]        [741.0]    [730.0]       [912.0]    [849.0]       [u'PS']          [1451.0]     [u'NA']    [91.0]               [79.0]            [u'NaN']   [23.0]      [11.0]      [u'SAN']  [u'SFO']  [447.0]     [u'NaN']  [u'NaN']   [0.0]        [u'NA']             [0.0]       [u'NaN']        [u'NaN']        [u'NaN']    [u'NaN']         [u'NaN']             [u'YES']        [u'YES']
#        2  [1987.0]  [10.0]   [15.0]        [4.0]        [729.0]    [730.0]       [903.0]    [849.0]       [u'PS']          [1451.0]     [u'NA']    [94.0]               [79.0]            [u'NaN']   [14.0]      [-1.0]      [u'SAN']  [u'SFO']  [447.0]     [u'NaN']  [u'NaN']   [0.0]        [u'NA']             [0.0]       [u'NaN']        [u'NaN']        [u'NaN']    [u'NaN']         [u'NaN']             [u'YES']        [u'NO']
#        3  [1987.0]  [10.0]   [17.0]        [6.0]        [741.0]    [730.0]       [918.0]    [849.0]       [u'PS']          [1451.0]     [u'NA']    [97.0]               [79.0]            [u'NaN']   [29.0]      [11.0]      [u'SAN']  [u'SFO']  [447.0]     [u'NaN']  [u'NaN']   [0.0]        [u'NA']             [0.0]       [u'NaN']        [u'NaN']        [u'NaN']    [u'NaN']         [u'NaN']             [u'YES']        [u'YES']
#        4  [1987.0]  [10.0]   [18.0]        [7.0]        [729.0]    [730.0]       [847.0]    [849.0]       [u'PS']          [1451.0]     [u'NA']    [78.0]               [79.0]            [u'NaN']   [-2.0]      [-1.0]      [u'SAN']  [u'SFO']  [447.0]     [u'NaN']  [u'NaN']   [0.0]        [u'NA']             [0.0]       [u'NaN']        [u'NaN']        [u'NaN']    [u'NaN']         [u'NaN']             [u'NO']         [u'NO']
#        5  [1987.0]  [10.0]   [19.0]        [1.0]        [749.0]    [730.0]       [922.0]    [849.0]       [u'PS']          [1451.0]     [u'NA']    [93.0]               [79.0]            [u'NaN']   [33.0]      [19.0]      [u'SAN']  [u'SFO']  [447.0]     [u'NaN']  [u'NaN']   [0.0]        [u'NA']             [0.0]       [u'NaN']        [u'NaN']        [u'NaN']    [u'NaN']         [u'NaN']             [u'YES']        [u'YES']
#        6  [1987.0]  [10.0]   [21.0]        [3.0]        [728.0]    [730.0]       [848.0]    [849.0]       [u'PS']          [1451.0]     [u'NA']    [80.0]               [79.0]            [u'NaN']   [-1.0]      [-2.0]      [u'SAN']  [u'SFO']  [447.0]     [u'NaN']  [u'NaN']   [0.0]        [u'NA']             [0.0]       [u'NaN']        [u'NaN']        [u'NaN']    [u'NaN']         [u'NaN']             [u'NO']         [u'NO']
#        7  [1987.0]  [10.0]   [22.0]        [4.0]        [728.0]    [730.0]       [852.0]    [849.0]       [u'PS']          [1451.0]     [u'NA']    [84.0]               [79.0]            [u'NaN']   [3.0]       [-2.0]      [u'SAN']  [u'SFO']  [447.0]     [u'NaN']  [u'NaN']   [0.0]        [u'NA']             [0.0]       [u'NaN']        [u'NaN']        [u'NaN']    [u'NaN']         [u'NaN']             [u'YES']        [u'NO']
#        8  [1987.0]  [10.0]   [23.0]        [5.0]        [731.0]    [730.0]       [902.0]    [849.0]       [u'PS']          [1451.0]     [u'NA']    [91.0]               [79.0]            [u'NaN']   [13.0]      [1.0]       [u'SAN']  [u'SFO']  [447.0]     [u'NaN']  [u'NaN']   [0.0]        [u'NA']             [0.0]       [u'NaN']        [u'NaN']        [u'NaN']    [u'NaN']         [u'NaN']             [u'YES']        [u'YES']
#        9  [1987.0]  [10.0]   [24.0]        [6.0]        [744.0]    [730.0]       [908.0]    [849.0]       [u'PS']          [1451.0]     [u'NA']    [84.0]               [79.0]            [u'NaN']   [19.0]      [14.0]      [u'SAN']  [u'SFO']  [447.0]     [u'NaN']  [u'NaN']   [0.0]        [u'NA']             [0.0]       [u'NaN']        [u'NaN']        [u'NaN']    [u'NaN']         [u'NaN']             [u'YES']        [u'YES']
#       10  [1987.0]  [10.0]   [25.0]        [7.0]        [729.0]    [730.0]       [851.0]    [849.0]       [u'PS']          [1451.0]     [u'NA']    [82.0]               [79.0]            [u'NaN']   [2.0]       [-1.0]      [u'SAN']  [u'SFO']  [447.0]     [u'NaN']  [u'NaN']   [0.0]        [u'NA']             [0.0]       [u'NaN']        [u'NaN']        [u'NaN']    [u'NaN']         [u'NaN']             [u'YES']        [u'NO']

# %%
air = h2o.upload_file(h2o.locate("smalldata/airlines/allyears2k_headers.zip"))
# Out:
# Parse Progress: [                                                  ] 00%
# Parse Progress: [##################################################] 100%
# Uploaded py292f98df-b173-4bc0-83c8-481d85387997 into cluster with 43978 rows and 31 cols

# %%
h2o.impute(air, "TailNum", method = "mode").show()
# Out:
# Displaying 10 row(s):
#   Row ID  Year      Month    DayofMonth    DayOfWeek    DepTime    CRSDepTime    ArrTime    CRSArrTime    UniqueCarrier    FlightNum    TailNum    ActualElapsedTime    CRSElapsedTime    AirTime    ArrDelay    DepDelay    Origin    Dest      Distance    TaxiIn    TaxiOut    Cancelled    CancellationCode    Diverted    CarrierDelay    WeatherDelay    NASDelay    SecurityDelay    LateAircraftDelay    IsArrDelayed    IsDepDelayed
# --------  --------  -------  ------------  -----------  ---------  ------------  ---------  ------------  ---------------  -----------  ---------  -------------------  ----------------  ---------  ----------  ----------  --------  --------  ----------  --------  ---------  -----------  ------------------  ----------  --------------  --------------  ----------  ---------------  -------------------  --------------  --------------
#        1  [1987.0]  [10.0]   [14.0]        [3.0]        [741.0]    [730.0]       [912.0]    [849.0]       [u'PS']          [1451.0]     [u'NA']    [91.0]               [79.0]            [u'NaN']   [23.0]      [11.0]      [u'SAN']  [u'SFO']  [447.0]     [u'NaN']  [u'NaN']   [0.0]        [u'NA']             [0.0]       [u'NaN']        [u'NaN']        [u'NaN']    [u'NaN']         [u'NaN']             [u'YES']        [u'YES']
#        2  [1987.0]  [10.0]   [15.0]        [4.0]        [729.0]    [730.0]       [903.0]    [849.0]       [u'PS']          [1451.0]     [u'NA']    [94.0]               [79.0]            [u'NaN']   [14.0]      [-1.0]      [u'SAN']  [u'SFO']  [447.0]     [u'NaN']  [u'NaN']   [0.0]        [u'NA']             [0.0]       [u'NaN']        [u'NaN']        [u'NaN']    [u'NaN']         [u'NaN']             [u'YES']        [u'NO']
#        3  [1987.0]  [10.0]   [17.0]        [6.0]        [741.0]    [730.0]       [918.0]    [849.0]       [u'PS']          [1451.0]     [u'NA']    [97.0]               [79.0]            [u'NaN']   [29.0]      [11.0]      [u'SAN']  [u'SFO']  [447.0]     [u'NaN']  [u'NaN']   [0.0]        [u'NA']             [0.0]       [u'NaN']        [u'NaN']        [u'NaN']    [u'NaN']         [u'NaN']             [u'YES']        [u'YES']
#        4  [1987.0]  [10.0]   [18.0]        [7.0]        [729.0]    [730.0]       [847.0]    [849.0]       [u'PS']          [1451.0]     [u'NA']    [78.0]               [79.0]            [u'NaN']   [-2.0]      [-1.0]      [u'SAN']  [u'SFO']  [447.0]     [u'NaN']  [u'NaN']   [0.0]        [u'NA']             [0.0]       [u'NaN']        [u'NaN']        [u'NaN']    [u'NaN']         [u'NaN']             [u'NO']         [u'NO']
#        5  [1987.0]  [10.0]   [19.0]        [1.0]        [749.0]    [730.0]       [922.0]    [849.0]       [u'PS']          [1451.0]     [u'NA']    [93.0]               [79.0]            [u'NaN']   [33.0]      [19.0]      [u'SAN']  [u'SFO']  [447.0]     [u'NaN']  [u'NaN']   [0.0]        [u'NA']             [0.0]       [u'NaN']        [u'NaN']        [u'NaN']    [u'NaN']         [u'NaN']             [u'YES']        [u'YES']
#        6  [1987.0]  [10.0]   [21.0]        [3.0]        [728.0]    [730.0]       [848.0]    [849.0]       [u'PS']          [1451.0]     [u'NA']    [80.0]               [79.0]            [u'NaN']   [-1.0]      [-2.0]      [u'SAN']  [u'SFO']  [447.0]     [u'NaN']  [u'NaN']   [0.0]        [u'NA']             [0.0]       [u'NaN']        [u'NaN']        [u'NaN']    [u'NaN']         [u'NaN']             [u'NO']         [u'NO']
#        7  [1987.0]  [10.0]   [22.0]        [4.0]        [728.0]    [730.0]       [852.0]    [849.0]       [u'PS']          [1451.0]     [u'NA']    [84.0]               [79.0]            [u'NaN']   [3.0]       [-2.0]      [u'SAN']  [u'SFO']  [447.0]     [u'NaN']  [u'NaN']   [0.0]        [u'NA']             [0.0]       [u'NaN']        [u'NaN']        [u'NaN']    [u'NaN']         [u'NaN']             [u'YES']        [u'NO']
#        8  [1987.0]  [10.0]   [23.0]        [5.0]        [731.0]    [730.0]       [902.0]    [849.0]       [u'PS']          [1451.0]     [u'NA']    [91.0]               [79.0]            [u'NaN']   [13.0]      [1.0]       [u'SAN']  [u'SFO']  [447.0]     [u'NaN']  [u'NaN']   [0.0]        [u'NA']             [0.0]       [u'NaN']        [u'NaN']        [u'NaN']    [u'NaN']         [u'NaN']             [u'YES']        [u'YES']
#        9  [1987.0]  [10.0]   [24.0]        [6.0]        [744.0]    [730.0]       [908.0]    [849.0]       [u'PS']          [1451.0]     [u'NA']    [84.0]               [79.0]            [u'NaN']   [19.0]      [14.0]      [u'SAN']  [u'SFO']  [447.0]     [u'NaN']  [u'NaN']   [0.0]        [u'NA']             [0.0]       [u'NaN']        [u'NaN']        [u'NaN']    [u'NaN']         [u'NaN']             [u'YES']        [u'YES']
#       10  [1987.0]  [10.0]   [25.0]        [7.0]        [729.0]    [730.0]       [851.0]    [849.0]       [u'PS']          [1451.0]     [u'NA']    [82.0]               [79.0]            [u'NaN']   [2.0]       [-1.0]      [u'SAN']  [u'SFO']  [447.0]     [u'NaN']  [u'NaN']   [0.0]        [u'NA']             [0.0]       [u'NaN']        [u'NaN']        [u'NaN']    [u'NaN']         [u'NaN']             [u'YES']        [u'NO']

# %%
air = h2o.upload_file(h2o.locate("smalldata/airlines/allyears2k_headers.zip"))
# Out:
# Parse Progress: [                                                  ] 00%
# Parse Progress: [##################################################] 100%
# Uploaded py28d3fe04-8784-4276-9825-baae34cc6ab4 into cluster with 43978 rows and 31 cols

# %%
h2o.impute(air, "TailNum", method = "mode", by=["Month", "Year"]).show()
# Out:
# Displaying 10 row(s):
#   Row ID  Year      Month    DayofMonth    DayOfWeek    DepTime    CRSDepTime    ArrTime    CRSArrTime    UniqueCarrier    FlightNum    TailNum    ActualElapsedTime    CRSElapsedTime    AirTime    ArrDelay    DepDelay    Origin    Dest      Distance    TaxiIn    TaxiOut    Cancelled    CancellationCode    Diverted    CarrierDelay    WeatherDelay    NASDelay    SecurityDelay    LateAircraftDelay    IsArrDelayed    IsDepDelayed
# --------  --------  -------  ------------  -----------  ---------  ------------  ---------  ------------  ---------------  -----------  ---------  -------------------  ----------------  ---------  ----------  ----------  --------  --------  ----------  --------  ---------  -----------  ------------------  ----------  --------------  --------------  ----------  ---------------  -------------------  --------------  --------------
#        1  [1987.0]  [10.0]   [14.0]        [3.0]        [741.0]    [730.0]       [912.0]    [849.0]       [u'PS']          [1451.0]     [u'NA']    [91.0]               [79.0]            [u'NaN']   [23.0]      [11.0]      [u'SAN']  [u'SFO']  [447.0]     [u'NaN']  [u'NaN']   [0.0]        [u'NA']             [0.0]       [u'NaN']        [u'NaN']        [u'NaN']    [u'NaN']         [u'NaN']             [u'YES']        [u'YES']
#        2  [1987.0]  [10.0]   [15.0]        [4.0]        [729.0]    [730.0]       [903.0]    [849.0]       [u'PS']          [1451.0]     [u'NA']    [94.0]               [79.0]            [u'NaN']   [14.0]      [-1.0]      [u'SAN']  [u'SFO']  [447.0]     [u'NaN']  [u'NaN']   [0.0]        [u'NA']             [0.0]       [u'NaN']        [u'NaN']        [u'NaN']    [u'NaN']         [u'NaN']             [u'YES']        [u'NO']
#        3  [1987.0]  [10.0]   [17.0]        [6.0]        [741.0]    [730.0]       [918.0]    [849.0]       [u'PS']          [1451.0]     [u'NA']    [97.0]               [79.0]            [u'NaN']   [29.0]      [11.0]      [u'SAN']  [u'SFO']  [447.0]     [u'NaN']  [u'NaN']   [0.0]        [u'NA']             [0.0]       [u'NaN']        [u'NaN']        [u'NaN']    [u'NaN']         [u'NaN']             [u'YES']        [u'YES']
#        4  [1987.0]  [10.0]   [18.0]        [7.0]        [729.0]    [730.0]       [847.0]    [849.0]       [u'PS']          [1451.0]     [u'NA']    [78.0]               [79.0]            [u'NaN']   [-2.0]      [-1.0]      [u'SAN']  [u'SFO']  [447.0]     [u'NaN']  [u'NaN']   [0.0]        [u'NA']             [0.0]       [u'NaN']        [u'NaN']        [u'NaN']    [u'NaN']         [u'NaN']             [u'NO']         [u'NO']
#        5  [1987.0]  [10.0]   [19.0]        [1.0]        [749.0]    [730.0]       [922.0]    [849.0]       [u'PS']          [1451.0]     [u'NA']    [93.0]               [79.0]            [u'NaN']   [33.0]      [19.0]      [u'SAN']  [u'SFO']  [447.0]     [u'NaN']  [u'NaN']   [0.0]        [u'NA']             [0.0]       [u'NaN']        [u'NaN']        [u'NaN']    [u'NaN']         [u'NaN']             [u'YES']        [u'YES']
#        6  [1987.0]  [10.0]   [21.0]        [3.0]        [728.0]    [730.0]       [848.0]    [849.0]       [u'PS']          [1451.0]     [u'NA']    [80.0]               [79.0]            [u'NaN']   [-1.0]      [-2.0]      [u'SAN']  [u'SFO']  [447.0]     [u'NaN']  [u'NaN']   [0.0]        [u'NA']             [0.0]       [u'NaN']        [u'NaN']        [u'NaN']    [u'NaN']         [u'NaN']             [u'NO']         [u'NO']
#        7  [1987.0]  [10.0]   [22.0]        [4.0]        [728.0]    [730.0]       [852.0]    [849.0]       [u'PS']          [1451.0]     [u'NA']    [84.0]               [79.0]            [u'NaN']   [3.0]       [-2.0]      [u'SAN']  [u'SFO']  [447.0]     [u'NaN']  [u'NaN']   [0.0]        [u'NA']             [0.0]       [u'NaN']        [u'NaN']        [u'NaN']    [u'NaN']         [u'NaN']             [u'YES']        [u'NO']
#        8  [1987.0]  [10.0]   [23.0]        [5.0]        [731.0]    [730.0]       [902.0]    [849.0]       [u'PS']          [1451.0]     [u'NA']    [91.0]               [79.0]            [u'NaN']   [13.0]      [1.0]       [u'SAN']  [u'SFO']  [447.0]     [u'NaN']  [u'NaN']   [0.0]        [u'NA']             [0.0]       [u'NaN']        [u'NaN']        [u'NaN']    [u'NaN']         [u'NaN']             [u'YES']        [u'YES']
#        9  [1987.0]  [10.0]   [24.0]        [6.0]        [744.0]    [730.0]       [908.0]    [849.0]       [u'PS']          [1451.0]     [u'NA']    [84.0]               [79.0]            [u'NaN']   [19.0]      [14.0]      [u'SAN']  [u'SFO']  [447.0]     [u'NaN']  [u'NaN']   [0.0]        [u'NA']             [0.0]       [u'NaN']        [u'NaN']        [u'NaN']    [u'NaN']         [u'NaN']             [u'YES']        [u'YES']
#       10  [1987.0]  [10.0]   [25.0]        [7.0]        [729.0]    [730.0]       [851.0]    [849.0]       [u'PS']          [1451.0]     [u'NA']    [82.0]               [79.0]            [u'NaN']   [2.0]       [-1.0]      [u'SAN']  [u'SFO']  [447.0]     [u'NaN']  [u'NaN']   [0.0]        [u'NA']             [0.0]       [u'NaN']        [u'NaN']        [u'NaN']    [u'NaN']         [u'NaN']             [u'YES']        [u'NO']
